# %%
 #VIDHYASHREE G S - AMB2292

# %%
file=open("gkvk.txt","r")
content=file.read()       #if file does not found it shows an error,after that write file and execute it reads content
print(content)                 # readline it shows only first line
file.close()                   #readlines it shows all the lines
# Out:
# new content

# %%
file=open("gkvk.txt","w")
file.write("hello tanu sindhu ")         #in write mode if file does not exist ,it creates file
file.close()

# %%
file=open("gkvk.txt","a")             #old content is not deleted,so it adds content at end of the file
file.write(" \n welcome to gkvk ")        #file will be created if does not exist
file.close()

# %%
file=open("abc.txt","a")                 #if file does not exist file created
file.write("hello vaishu")
file.close()

# %%
with open("gkvk.txt","r") as file:  # no need to put syntax of close()
    print(file.read())
# Out:
# hello tanu sindhu
#  welcome to gkvk

# %%
with open("gkvk.txt","w") as file:
    file.write("new content")

# %%
try:
      file("vidhya.txt","r")    #exceptional handling files ,file not found error handled by try and except method
      content=file.read()
      print(content)
      file.close()
except:
      print("file does not exist")
# Out:
# file does not exist

# %%
try:
     with open("vidhya.txt","r") as file:
          line=file.read()
          print(line)                    # with method
except:
     print("file does not exist")
# Out:
# file does not exist

# %%
try:
    a=30
    b=20
    c=a+d
    print(c)
except:
  print("some issue")
# Out:
# some issue

# %%
def expr(a,b):
  c=a/b
  print(c)
a=10
b=5
expr(a,b)
# Out:
# 2.0

# %%
def expr(a,b):
  try:
         c=a/F
  except ZeroDivisionError: #IF aything divided by o it gives this error
         print(" divided by zero")
  except NameError:
         print("variable not found") #if a/f
  except:
         print("some issue")
  else:
       print("excecuted without errors")
  finally:
       print("end of the program")

a=19
b=0
expr(a,b)
# Out:
# variable not found
# end of the program
