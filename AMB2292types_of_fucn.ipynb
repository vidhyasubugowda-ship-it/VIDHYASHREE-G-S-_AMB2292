# %%
#VIDHYASHREE G S -AMB2292

# %%
#scope of variables
def func(x):
  print("local x is: ",x)
  x=2
  print("changed local x to: ",x)
x=50
func(x)
print("x still :",x)
# Out:
# local x is:  50
# changed local x to:  2
# x still : 50

# %%
def fucn1():
  global y
  print("y is :",y)
y=50
fucn1()
print("value of y is:", y)
# Out:
# y is : 50
# value of y is: 50

# %%
total=0
def sum(arg1,arg2):
  total=arg1+arg2
  print("inside the function local total:",total)
  return total
sum(10,20)
print("outside the function global total:",total)
# Out:
# inside the function local total: 30
# outside the function global total: 0

# %%
#required arguments
def printme(str):  # the number of parameter in fn header sld be same as in fn called statement
  print(str)
 #return
print(("hello"))    #print() statement gives an error
printme(1234)
# Out:
# hello
# 1234

# %%
#key word/named arguments
def printme(str):
 print(str)
 return
printme("hello")#required arguments
#now call print me
printme(str="my string")#named arguents
#printme(abc="my string")# gives an error abc is unknown
# Out:
# hello
# my string

# %%
#default argument
def fucn(a,b=1,c=3):
  print("a is:",a, "b is:",b,"c is:",c)
fucn(3,7)
fucn(25,c=24)
fucn(c=50,a=100)
# Out:
# a is: 3 b is: 7 c is: 3
# a is: 25 b is: 1 c is: 24
# a is: 100 b is: 1 c is: 50

# %%
def fucn(a,b,c):
  print("a is:",a, "b is:",b,"c is:",c)
fucn(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1927350354.py in <cell line: 0>()
#       1 def fucn(a,b,c):
#       2   print("a is:",a, "b is:",b,"c is:",c)
# ----> 3 fucn(3,4)
#
# TypeError: fucn() missing 1 required positional argument: 'c'

# %%
#variable-length argument
def check(name,*marks):#  "*" holds multiple values
  print(name)
  print(marks)
check("x,y,z",10,20,30)
# Out:
# x,y,z
# (10, 20, 30)
